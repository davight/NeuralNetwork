# %%
import kagglehub


kagglehub.dataset_download("nalisha/job-salary-prediction-dataset", output_dir="./data")
# Out:
# ...
# 100%|██████████| 3.00M/3.00M [00:01<00:00, 1.59MB/s]
# Extracting files...
